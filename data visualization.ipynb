# %%
import pandas
import matplotlib
import seaborn as sn

# %%
iris=sn.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sn.set_style('dark')
sn.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_length'],shade=True,color='c',Label='setosa')

# %%
sn.set_style('dark')
sn.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_length'],shade=True,color='k',Label='setosa')
sn.set_style('dark')
sn.kdeplot(iris.loc[(iris['species']=='versicolor'),'sepal_length'],shade=True,color='r',Label='versicolor')

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(iris.sepal_length,iris.sepal_width)
sn.set()
plt.show()

# %%
sn.set(style="darkgrid")
from matplotlib import pyplot as plt
iris=sn.load_dataset('iris')
sn.boxplot(x=iris['species'],y=iris['sepal_length'])
plt.show()

# %%
x=iris.species
y=iris.petal_length
fig,ax=plt.subplots()
ax.plot(y)

# %%
from matplotlib import pyplot as plt
x=iris.petal_length
plt.hist(x,bins=20,color='r')
plt.title('petal_length')
plt.show()

# %%
iris=sn.load_dataset('iris')
from matplotlib import pyplot as plt
x=iris.species
y=iris.petal_length
plt.bar(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(iris.sepal_length,iris.petal_length)
sn.set_style('darkgrid')

# %%
sn.relplot(data=iris,x="sepal_length",y='petal_length')

# %%
sn.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_width'],color='y',Label='setosa')
